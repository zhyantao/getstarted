# %% [markdown]
# # Matplotlib

# %% [markdown]
# Matplotlib是Python的二维绘图库，用于生成符合出版质量或跨平台交互环境的各类图形。

# %% [markdown]
# ## 准备数据

# %% [markdown]
# ### 一维数据

# %%
import numpy as np

# %%
x = np.linspace(0, 10, 100)

# %%
y = np.cos(x)

# %%
z = np.sin(x)

# %% [markdown]
# ### 二维数据或图片

# %%
data = 2 * np.random.random((10, 10))

# %%
data2 = 3 * np.random.random((10, 10))

# %%
Y, X = np.mgrid[-3:3:100j, -3:3:100j]

# %%
U = -1 - X**2 + Y

# %%
V = 1 + X - Y**2

# %% [markdown]
# ## 绘制图形

# %% [markdown]
# ### 导入库

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 画布

# %%
fig = plt.figure()

# %%
fig2 = plt.figure(figsize=plt.figaspect(2.0))

# %% [markdown]
# ### 坐标轴

# %% [markdown]
# **图形是以坐标轴为核心绘制的，大多数情况下，子图就可以满足需求。子图是栅格系统的坐标轴。**

# %%
ax1 = fig.add_subplot(221)  # row-col-num

# %%
ax3 = fig.add_subplot(212)

# %%
fig3, axes = plt.subplots(nrows=2, ncols=2)

# %%
fig4, axes2 = plt.subplots(ncols=3)

# %%
fig.add_axes(ax1)
# Out:
# <Axes: >

# %% [markdown]
# ## 绘图例程

# %% [markdown]
# ### 一维数据

# %%
fig, ax = plt.subplots()

# %%
lines = ax.plot(x, y)  # 用线或标记连接点

# %%
ax.scatter(x, y)  # 缩放或着色未连接的点

# %%
axes[0, 0].bar([1, 2, 3], [3, 4, 5])  # 绘制柱状图
# Out:
# <BarContainer object of 3 artists>

# %%
axes[1, 0].barh([0.5, 1, 2.5], [0, 1, 2])  # 绘制水平柱状图
# Out:
# <BarContainer object of 3 artists>

# %%
axes[1, 1].axhline(0.45)  # 绘制与轴平行的横线

# %%
axes[0, 1].axvline(0.65)  # 绘制与轴垂直的竖线

# %%
ax.fill(x, y, color="blue")  # 绘制填充多边形

# %%
ax.fill_between(x, y, color="yellow")  # 填充 y 值和 0 之间

# %% [markdown]
# ### 向量场

# %%
axes[0, 1].arrow(0, 0, 0.5, 0.5)  # 为坐标轴添加箭头

# %%
axes[1, 1].quiver(y, z)  # 二维箭头

# %%
axes[0, 1].streamplot(X, Y, U, V)  # 二维箭头

# %% [markdown]
# ### 数据分布

# %%
ax1.hist(y)  # 直方图
# Out:
# (array([26.,  8.,  7.,  6.,  6.,  6.,  6.,  7.,  8., 20.]),
#  array([-9.99947166e-01, -7.99952450e-01, -5.99957733e-01, -3.99963016e-01,
#         -1.99968300e-01,  2.64169119e-05,  2.00021134e-01,  4.00015850e-01,
#          6.00010567e-01,  8.00005283e-01,  1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
ax3.boxplot(y)  # 箱形图
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1f5855b16d0>,
#   <matplotlib.lines.Line2D at 0x1f5855c14c0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1f5855c1d90>,
#   <matplotlib.lines.Line2D at 0x1f585627580>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1f5855b1520>],
#  'medians': [<matplotlib.lines.Line2D at 0x1f585627e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1f58564d310>],
#  'means': []}

# %%
ax3.violinplot(z)  # 小提琴图
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1f58564c550>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1f58564ddc0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1f585886670>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1f585894700>}

# %% [markdown]
# ### 二维数据或图片

# %%
fig, ax = plt.subplots()

# %%
axes2[0].pcolor(data2)  # 二维数组伪彩色图

# %%
axes2[0].pcolormesh(data)  # 二维数组等高线伪彩色图

# %%
CS = plt.contour(Y, X, U)  # 等高线图

# %%
axes2[2] = ax.clabel(CS)  # 等高线图标签

# %% [markdown]
# ## 图形解析与工作流

# %% [markdown]
# ### 图形解析

# %% [markdown]
# ### 工作流

# %% [markdown]
# Matplotlib 绘图的基本步骤：
# - Step 1 准备数据
# - Step 2 创建图形
# - Step 3 绘图
# - Step 4 自定义设置
# - Step 5 保存图形
# - Step 6 显示图形

# %%
import matplotlib.pyplot as plt

# %%
x = [1, 2, 3, 4]  # Step 1

# %%
y = [10, 20, 25, 30]

# %%
fig = plt.figure()  # Step 2

# %%
ax = fig.add_subplot(111)  # Step 3

# %%
ax.plot(x, y, color="lightblue", linewidth=3)  # Step 3, 4

# %%
ax.scatter([2, 4, 6], [5, 15, 25], color="darkgreen", marker="^")

# %%
ax.set_xlim(1, 6.5)
# Out:
# (1.0, 6.5)

# %%
plt.savefig("../../_tmp/plt_savefig.png")  # Step 5

# %%
plt.show()  # Step 6

# %% [markdown]
# ## 自定义图形

# %% [markdown]
# ### 颜色、色条与色彩表

# %%
plt.plot(x, x, x, [i**2 for i in x], x, [i**3 for i in x])
# Out:
# [<matplotlib.lines.Line2D at 0x1f584df7700>,
#  <matplotlib.lines.Line2D at 0x1f584df7760>,
#  <matplotlib.lines.Line2D at 0x1f584df7790>]

# %%
ax.plot(x, y, alpha=0.4)

# %%
ax.plot(x, y, c="k")

# %% [markdown]
# ### 标记

# %%
fig, ax = plt.subplots()

# %%
ax.scatter(x, y, marker=".")

# %%
ax.plot(x, y, marker="o")

# %% [markdown]
# ### 线型

# %%
plt.plot(x, y, linewidth=4.0)

# %%
plt.plot(x, y, ls="solid")

# %%
plt.plot(x, y, ls="--")

# %%
plt.plot(x, y, "--", [i**2 for i in x], [i**2 for i in y], "-.")
# Out:
# [<matplotlib.lines.Line2D at 0x1f586338f40>,
#  <matplotlib.lines.Line2D at 0x1f5863460a0>]

# %%
plt.setp(lines, color="r", linewidth=4.0)
# Out:
# [None, None]

# %% [markdown]
# ### 文本与标注

# %%
ax.text(1, -2.1, "Example Graph", style="italic")
# Out:
# Text(1, -2.1, 'Example Graph')

# %%
ax.annotate(
    "Sine",
    xy=(8, 0),
    xycoords="data",
    xytext=(10.5, 0),
    textcoords="data",
    arrowprops=dict(arrowstyle="->", connectionstyle="arc3"),
)
# Out:
# Text(10.5, 0, 'Sine')

# %% [markdown]
# ### 数学符号

# %%
plt.title(r"$sigma_i=15$", fontsize=20)
# Out:
# Text(0.5, 1.0, '$sigma_i=15$')

# %% [markdown]
# ### 尺寸限制、图例和布局

# %% [markdown]
# **尺寸限制与自动调整**

# %%
ax.margins(x=0.0, y=0.1)  # 添加内边距

# %%
ax.axis("equal")  # 将图形纵横比设置为 1
# Out:
# (1.0, 4.0, 8.0, 32.0)

# %%
ax.set(xlim=[0, 10.5], ylim=[-1.5, 1.5])  # 设置 x 轴与 y 轴的限制
# Out:
# [(0.0, 10.5), (-1.5, 1.5)]

# %%
ax.set_xlim(0, 10.5)  # 设置 x 轴的限制
# Out:
# (0.0, 10.5)

# %% [markdown]
# **图例**

# %%
ax.set(title="An Example Axes", ylabel="Y-Axis", xlabel="X-Axis")  # 设置标题与 x、y 轴的标签
# Out:
# [Text(0.5, 1.0, 'An Example Axes'),
#  Text(4.444444444444445, 0.5, 'Y-Axis'),
#  Text(0.5, 4.444444444444445, 'X-Axis')]

# %%
ax.legend(loc="best")  # 自动选择最佳的图例位置
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# **标记**

# %%
ax.xaxis.set(ticks=range(1, 5), ticklabels=[3, 100, -12, "foo"])  # 手动设置 X 轴刻度
# Out:
# [[<matplotlib.axis.XTick at 0x1f584e5b520>,
#   <matplotlib.axis.XTick at 0x1f584e5b4f0>,
#   <matplotlib.axis.XTick at 0x1f584e2ceb0>,
#   <matplotlib.axis.XTick at 0x1f584e8a8b0>],
#  [Text(1, 0, '3'), Text(2, 0, '100'), Text(3, 0, '-12'), Text(4, 0, 'foo')]]

# %%
ax.tick_params(axis="y", direction="inout", length=10)  # 设置 Y 轴长度与方向

# %% [markdown]
# **子图间距**

# %%
fig3.subplots_adjust(
    wspace=0.5, hspace=0.3, left=0.125, right=0.9, top=0.9, bottom=0.1
)  # 调整子图间距

# %%
fig.tight_layout()  # 设置画布的子图布局

# %% [markdown]
# **坐标轴边线**

# %%
ax1.spines["top"].set_visible(False)  # 隐藏顶部坐标轴线

# %%
ax1.spines["bottom"].set_position(("outward", 10))  # 设置底部边线的位置为 outward

# %% [markdown]
# ## 保存

# %% [markdown]
# **savefig函数**

# %%
plt.savefig("../../_tmp/plt_savefig.png")  # 保存画布

# %%
plt.savefig("../../_tmp/plt_savefig_transparent.png", transparent=True)  # 保存透明画布

# %% [markdown]
# ##  显示图形

# %% [markdown]
# **show函数**

# %%
plt.show()

# %% [markdown]
# ## 关闭与清除

# %% [markdown]
# **绘图清除与关闭**

# %%
plt.cla()  # 清除坐标轴

# %%
plt.clf()  # 清除画布

# %%
plt.close()  # 关闭窗口
